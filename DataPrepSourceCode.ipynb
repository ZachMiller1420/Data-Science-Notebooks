# %% [markdown]
# # Test Connection to local Llama3 model running in a container

# %%
import requests
import json

# Define the URL and the payload
url = "http://172.18.0.2:11434/api/generate"
payload = {
    "model": "llama3",
    "prompt": "Why is the sky blue?"
}
headers = {
    "Content-Type": "application/json"
}

# Send the POST request
response = requests.post(url, data=json.dumps(payload), headers=headers)

# Print the raw response text
print("Raw response text:", response.text)

# Check the response
if response.status_code == 200:
    try:
        print("Response JSON:", response.json())
    except json.JSONDecodeError as e:
        print("Failed to decode JSON:", e)
else:
    print("Failed to get a response:", response.status_code, response.text)
# Out:
# Raw response text: {"model":"llama3","created_at":"2024-07-29T03:41:07.580713743Z","response":"The","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:07.602549018Z","response":" sky","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:07.623744769Z","response":" appears","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:07.645529023Z","response":" blue","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:07.666944307Z","response":" because","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:07.688095456Z","response":" of","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:07.709388727Z","response":" a","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:07.730645266Z","response":" phenomenon","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:07.752357046Z","response":" called","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:07.772525559Z","response":" Ray","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:07.793044236Z","response":"leigh","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:07.812205917Z","response":" scattering","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:07.83071018Z","response":",","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:07.849245905Z","response":" which","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:07.867194022Z","response":" is","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:07.885642477Z","response":" named","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:07.903876364Z","response":" after","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:07.92157773Z","response":" the","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:07.94037123Z","response":" British","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:07.958036263Z","response":" physicist","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:07.975945167Z","response":" Lord","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:07.99326906Z","response":" Ray","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:08.010658598Z","response":"leigh","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:08.028074494Z","response":".","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:08.046437643Z","response":" He","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:08.064643898Z","response":" discovered","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:08.085425867Z","response":" that","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:08.10313299Z","response":" when","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:08.120557119Z","response":" sunlight","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:08.138414069Z","response":" enters","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:08.160276079Z","response":" Earth","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:08.177942769Z","response":"'s","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:08.195513163Z","response":" atmosphere","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:08.213333957Z","response":",","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:08.231578806Z","response":" it","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:08.250563517Z","response":" encounters","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:08.269364293Z","response":" tiny","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:08.295178105Z","response":" molecules","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:08.314766561Z","response":" of","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:08.332281268Z","response":" gases","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:08.350223348Z","response":" such","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:08.367762957Z","response":" as","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:08.385475879Z","response":" nitrogen","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:08.403354148Z","response":" (","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:08.420913711Z","response":"N","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:08.438520367Z","response":"2","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:08.458311736Z","response":")","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:08.475823659Z","response":" and","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:08.493347818Z","response":" oxygen","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:08.515646219Z","response":" (","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:08.539915413Z","response":"O","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:08.562143959Z","response":"2","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:08.579483849Z","response":").","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:08.597279432Z","response":" These","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:08.615281021Z","response":" molecules","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:08.632761229Z","response":" scatter","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:08.650304725Z","response":" the","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:08.670919617Z","response":" light","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:08.695290163Z","response":" in","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:08.716698248Z","response":" all","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:08.734122526Z","response":" directions","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:08.75177762Z","response":",","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:08.769345836Z","response":" but","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:08.787054651Z","response":" they","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:08.805059328Z","response":" scatter","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:08.823285221Z","response":" shorter","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:08.841680645Z","response":" (","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:08.865928352Z","response":"blue","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:08.884712865Z","response":")","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:08.902546493Z","response":" wavelengths","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:08.92708487Z","response":" more","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:08.946823561Z","response":" than","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:08.964354036Z","response":" longer","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:08.98212632Z","response":" (","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:09.00018424Z","response":"red","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:09.018090214Z","response":")","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:09.035781731Z","response":" wavelengths","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:09.055692343Z","response":".\n\n","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:09.073480698Z","response":"Here","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:09.091173971Z","response":"'s","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:09.108909313Z","response":" what","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:09.126646388Z","response":" happens","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:09.145056579Z","response":":\n\n","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:09.163379745Z","response":"1","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:09.181618859Z","response":".","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:09.199939626Z","response":" When","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:09.217739538Z","response":" sunlight","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:09.241264229Z","response":" enters","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:09.258701283Z","response":" the","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:09.277092362Z","response":" atmosphere","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:09.29539259Z","response":",","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:09.313358963Z","response":" it","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:09.331469292Z","response":" consists","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:09.34927887Z","response":" of","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:09.367009984Z","response":" a","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:09.384850356Z","response":" broad","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:09.402741912Z","response":" spectrum","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:09.420751726Z","response":" of","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:09.438530226Z","response":" colors","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:09.456369851Z","response":",","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:09.474040451Z","response":" including","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:09.491822358Z","response":" all","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:09.509508757Z","response":" the","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:09.527522006Z","response":" colors","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:09.545561224Z","response":" of","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:09.565135486Z","response":" the","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:09.58382907Z","response":" rainbow","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:09.601668795Z","response":".\n","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:09.619691879Z","response":"2","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:09.644643167Z","response":".","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:09.671260879Z","response":" The","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:09.693645255Z","response":" tiny","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:09.711411054Z","response":" gas","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:09.72888521Z","response":" molecules","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:09.746974248Z","response":" in","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:09.764754452Z","response":" the","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:09.783316797Z","response":" air","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:09.804042148Z","response":",","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:09.823780474Z","response":" such","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:09.841431367Z","response":" as","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:09.858944193Z","response":" N","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:09.876493724Z","response":"2","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:09.894141233Z","response":" and","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:09.912228858Z","response":" O","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:09.930417021Z","response":"2","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:09.94850429Z","response":",","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:09.966139358Z","response":" are","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:09.985812817Z","response":" much","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:10.009806363Z","response":" smaller","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:10.030767104Z","response":" than","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:10.048287552Z","response":" the","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:10.072671323Z","response":" wavelength","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:10.096990324Z","response":" of","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:10.114473141Z","response":" light","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:10.132010146Z","response":".","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:10.149586657Z","response":" They","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:10.167841478Z","response":" scatter","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:10.185793226Z","response":" the","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:10.203779337Z","response":" shorter","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:10.221781121Z","response":" blue","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:10.239368587Z","response":" wavelengths","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:10.263601609Z","response":" more","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:10.283678929Z","response":" efficiently","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:10.301369561Z","response":" than","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:10.319601979Z","response":" the","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:10.337520751Z","response":" longer","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:10.362005176Z","response":" red","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:10.381968885Z","response":" wavelengths","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:10.400068907Z","response":" because","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:10.418280998Z","response":" they","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:10.436836825Z","response":" are","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:10.454554284Z","response":" closer","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:10.472432343Z","response":" to","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:10.490470601Z","response":" the","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:10.508559755Z","response":" same","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:10.526175389Z","response":" size","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:10.549633413Z","response":" range","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:10.570788814Z","response":" as","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:10.59295878Z","response":" the","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:10.612664113Z","response":" molecules","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:10.630226365Z","response":" themselves","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:10.647982519Z","response":".\n","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:10.665803905Z","response":"3","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:10.68400647Z","response":".","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:10.7044119Z","response":" As","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:10.722022998Z","response":" a","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:10.739661486Z","response":" result","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:10.757299896Z","response":",","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:10.775168977Z","response":" the","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:10.793051882Z","response":" blue","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:10.811149829Z","response":" light","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:10.828980758Z","response":" is","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:10.846735426Z","response":" scattered","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:10.864290196Z","response":" in","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:10.882266298Z","response":" all","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:10.900634739Z","response":" directions","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:10.919123824Z","response":" by","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:10.937107671Z","response":" the","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:10.955232742Z","response":" gas","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:10.973083208Z","response":" molecules","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:10.99107423Z","response":",","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:11.008896854Z","response":" reaching","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:11.026668402Z","response":" our","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:11.04454027Z","response":" eyes","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:11.062277466Z","response":" from","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:11.080067422Z","response":" all","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:11.09803862Z","response":" parts","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:11.115828764Z","response":" of","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:11.133867556Z","response":" the","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:11.15142359Z","response":" sky","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:11.169563535Z","response":".\n","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:11.187360972Z","response":"4","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:11.205160884Z","response":".","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:11.229157984Z","response":" The","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:11.252007562Z","response":" other","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:11.269957543Z","response":" colors","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:11.287981821Z","response":" of","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:11.306000721Z","response":" the","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:11.325008119Z","response":" spectrum","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:11.343155144Z","response":",","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:11.367251513Z","response":" such","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:11.385091103Z","response":" as","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:11.403338034Z","response":" red","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:11.42368831Z","response":" and","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:11.44165696Z","response":" orange","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:11.462811132Z","response":",","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:11.480402348Z","response":" have","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:11.498303691Z","response":" longer","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:11.517384779Z","response":" wavelengths","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:11.535532554Z","response":" and","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:11.553676543Z","response":" are","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:11.572000657Z","response":" less","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:11.59104747Z","response":" affected","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:11.609330903Z","response":" by","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:11.627547437Z","response":" scattering","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:11.645731114Z","response":".","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:11.663679245Z","response":" They","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:11.681943425Z","response":" continue","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:11.700429104Z","response":" to","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:11.718450558Z","response":" travel","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:11.736527509Z","response":" in","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:11.754979934Z","response":" a","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:11.772763104Z","response":" more","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:11.790655658Z","response":" direct","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:11.808864647Z","response":" path","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:11.827044103Z","response":" to","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:11.84524981Z","response":" our","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:11.863772487Z","response":" eyes","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:11.881648027Z","response":",","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:11.899566738Z","response":" arriving","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:11.9173014Z","response":" after","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:11.935368403Z","response":" being","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:11.953265714Z","response":" delayed","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:11.971723534Z","response":" slightly","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:11.989790407Z","response":" by","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:12.007748193Z","response":" the","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:12.025794006Z","response":" longer","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:12.043737292Z","response":" distance","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:12.061536575Z","response":" they","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:12.079478528Z","response":"'ve","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:12.097455321Z","response":" traveled","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:12.115966978Z","response":".\n","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:12.134351052Z","response":"5","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:12.152530886Z","response":".","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:12.170751493Z","response":" Our","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:12.188890148Z","response":" brains","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:12.207142109Z","response":" combine","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:12.226051838Z","response":" these","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:12.243975913Z","response":" scattered","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:12.261977563Z","response":" blue","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:12.280202888Z","response":" colors","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:12.298424861Z","response":" with","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:12.317066613Z","response":" the","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:12.335717793Z","response":" direct","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:12.35401507Z","response":" red","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:12.377603454Z","response":" and","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:12.395731438Z","response":" orange","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:12.413688212Z","response":" light","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:12.434489335Z","response":",","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:12.452651924Z","response":" creating","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:12.470542114Z","response":" the","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:12.488496305Z","response":" sky","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:12.506678015Z","response":"'s","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:12.525426867Z","response":" familiar","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:12.544020819Z","response":" blue","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:12.56834681Z","response":" hue","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:12.58858796Z","response":".\n\n","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:12.606541446Z","response":"This","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:12.624499756Z","response":" is","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:12.642455926Z","response":" why","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:12.664243535Z","response":" the","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:12.682343235Z","response":" sky","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:12.700399305Z","response":" typically","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:12.718459315Z","response":" appears","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:12.736798012Z","response":" blue","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:12.755181424Z","response":" during","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:12.773022025Z","response":" the","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:12.79126951Z","response":" daytime","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:12.815645809Z","response":" when","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:12.837184224Z","response":" the","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:12.854970529Z","response":" sun","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:12.873028963Z","response":" is","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:12.891473016Z","response":" overhead","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:12.909591296Z","response":" and","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:12.927740782Z","response":" its","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:12.945879099Z","response":" rays","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:12.964298004Z","response":" pass","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:12.982547836Z","response":" through","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:13.001037505Z","response":" a","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:13.018882716Z","response":" shorter","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:13.036961489Z","response":" distance","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:13.05536574Z","response":" in","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:13.078768125Z","response":" the","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:13.097096177Z","response":" atmosphere","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:13.115450345Z","response":".","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:13.134010444Z","response":" During","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:13.152372903Z","response":" sunrise","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:13.170319797Z","response":" and","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:13.188467463Z","response":" sunset","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:13.206681148Z","response":",","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:13.224882603Z","response":" the","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:13.243030076Z","response":" sun","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:13.261261305Z","response":"'s","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:13.279668813Z","response":" rays","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:13.298776367Z","response":" travel","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:13.317043876Z","response":" longer","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:13.335191347Z","response":" distances","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:13.353465396Z","response":" through","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:13.371364531Z","response":" more","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:13.389421193Z","response":" of","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:13.407488827Z","response":" the","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:13.42553851Z","response":" Earth","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:13.443543701Z","response":"'s","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:13.46152326Z","response":" atmosphere","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:13.47975053Z","response":",","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:13.498295894Z","response":" scattering","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:13.51702152Z","response":" even","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:13.535252197Z","response":" more","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:13.55372204Z","response":" of","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:13.57188535Z","response":" the","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:13.589967419Z","response":" shorter","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:13.614032949Z","response":" blue","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:13.631732084Z","response":" wavelengths","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:13.649642134Z","response":",","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:13.66781567Z","response":" which","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:13.686089952Z","response":" makes","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:13.704051991Z","response":" the","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:13.722507574Z","response":" sky","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:13.740527377Z","response":" appear","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:13.758295945Z","response":" more","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:13.776441516Z","response":" orange","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:13.794459347Z","response":" or","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:13.812752395Z","response":" red","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:13.83082253Z","response":".\n\n","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:13.848864286Z","response":"So","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:13.867058686Z","response":",","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:13.885398488Z","response":" to","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:13.905395404Z","response":" summarize","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:13.923913793Z","response":":","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:13.94249716Z","response":" the","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:13.960617511Z","response":" sky","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:13.981612142Z","response":" appears","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:13.999637208Z","response":" blue","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:14.020398241Z","response":" because","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:14.038604387Z","response":" of","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:14.056835931Z","response":" the","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:14.074884715Z","response":" scattering","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:14.093062017Z","response":" of","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:14.116929286Z","response":" sunlight","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:14.137573602Z","response":" by","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:14.155459143Z","response":" tiny","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:14.173253375Z","response":" gas","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:14.191343199Z","response":" molecules","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:14.209282127Z","response":" in","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:14.22729609Z","response":" our","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:14.245310755Z","response":" atmosphere","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:14.263519907Z","response":",","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:14.282070227Z","response":" with","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:14.300591539Z","response":" shorter","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:14.318596749Z","response":" blue","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:14.336765438Z","response":" wavelengths","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:14.354735645Z","response":" being","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:14.372820366Z","response":" scattered","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:14.390994317Z","response":" more","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:14.409009064Z","response":" than","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:14.426974095Z","response":" longer","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:14.445445734Z","response":" red","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:14.465259455Z","response":" wavelengths","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:14.48375367Z","response":".","done":false}
# {"model":"llama3","created_at":"2024-07-29T03:41:14.501680999Z","response":"","done":true,"done_reason":"stop","context":[128006,882,128007,271,10445,374,279,13180,6437,30,128009,128006,78191,128007,271,791,13180,8111,6437,1606,315,264,25885,2663,13558,64069,72916,11,902,374,7086,1306,279,8013,83323,10425,13558,64069,13,1283,11352,430,994,40120,29933,9420,596,16975,11,433,35006,13987,35715,315,45612,1778,439,47503,320,45,17,8,323,24463,320,46,17,570,4314,35715,45577,279,3177,304,682,18445,11,719,814,45577,24210,320,12481,8,93959,810,1109,5129,320,1171,8,93959,382,8586,596,1148,8741,1473,16,13,3277,40120,29933,279,16975,11,433,17610,315,264,7353,20326,315,8146,11,2737,682,279,8146,315,279,48713,627,17,13,578,13987,6962,35715,304,279,3805,11,1778,439,452,17,323,507,17,11,527,1790,9333,1109,279,46406,315,3177,13,2435,45577,279,24210,6437,93959,810,30820,1109,279,5129,2579,93959,1606,814,527,12401,311,279,1890,1404,2134,439,279,35715,5694,627,18,13,1666,264,1121,11,279,6437,3177,374,38067,304,682,18445,555,279,6962,35715,11,19261,1057,6548,505,682,5596,315,279,13180,627,19,13,578,1023,8146,315,279,20326,11,1778,439,2579,323,19087,11,617,5129,93959,323,527,2753,11754,555,72916,13,2435,3136,311,5944,304,264,810,2167,1853,311,1057,6548,11,33111,1306,1694,23540,10284,555,279,5129,6138,814,3077,31796,627,20,13,5751,35202,16343,1521,38067,6437,8146,449,279,2167,2579,323,19087,3177,11,6968,279,13180,596,11537,6437,40140,382,2028,374,3249,279,13180,11383,8111,6437,2391,279,62182,994,279,7160,374,32115,323,1202,45220,1522,1555,264,24210,6138,304,279,16975,13,12220,64919,323,44084,11,279,7160,596,45220,5944,5129,27650,1555,810,315,279,9420,596,16975,11,72916,1524,810,315,279,24210,6437,93959,11,902,3727,279,13180,5101,810,19087,477,2579,382,4516,11,311,63179,25,279,13180,8111,6437,1606,315,279,72916,315,40120,555,13987,6962,35715,304,1057,16975,11,449,24210,6437,93959,1694,38067,810,1109,5129,2579,93959,13],"total_duration":7276901401,"load_duration":18343695,"prompt_eval_count":16,"prompt_eval_duration":293713000,"eval_count":370,"eval_duration":6920942000}
#
# Failed to decode JSON: Extra data: line 2 column 1 (char 95)

# %% [markdown]
# # Parse the API response from llama model

# %%
# Function to generate embeddings using the LLaMA model API
def generate_embeddings(file_content):
    url = "http://172.18.0.2:11434/api/generate" 
    headers = {'Content-Type': 'application/json'}
    
    data = {'prompt': f"Analyze the following code and create a detailed embedding that captures its functionality and structure:\n\n{file_content}",
            'model': 'llama3'
           }
    
    response = requests.post(url, headers=headers, json=data, stream=True)
    
    if response.status_code == 200:
        full_response = ""
        embeddings = []
        for line in response.iter_lines():
            if line:
                json_response = json.loads(line.decode('utf-8'))
                full_response += json_response.get('response', '')
                if 'context' in json_response:
                    embeddings = json_response['context']
                if json_response.get('done', False):
                    break
        return full_response, embeddings
    else:
        raise Exception(f"Failed to generate embeddings: {response.status_code} - {response.text}")

# Test the function
file_content = "print('Hello, World!')"
explanation, embeddings = generate_embeddings(file_content)
print("Explanation:", explanation)
print("Embeddings:", embeddings)
# Out:
# Explanation: What a classic!
#
# Here's a detailed analysis of the code:
#
# **Functionality:**
#
# The provided code is a simple print statement in Python. When executed, it will output the string "Hello, World!" to the console.
#
# **Structure:**
#
# The code consists of a single line that contains:
#
# 1. The `print()` function: This is a built-in Python function used to output its argument(s) to the console.
# 2. A quoted string: The string "Hello, World!" is enclosed in quotes (either single quotes '...' or double quotes "..."). This indicates that the contents within are a literal string.
#
# **Breakdown of the Code:**
#
# Here's a step-by-step breakdown of what happens when this code is executed:
#
# 1. The `print()` function is called with the argument `"Hello, World!"`.
# 2. The Python interpreter encounters the quoted string and treats it as a literal value.
# 3. The `print()` function takes the quoted string as input and outputs it to the console using the platform's default output mechanism (e.g., stdout).
# 4. The output is displayed in the console or terminal window, showing the string "Hello, World!".
#
# **Key Aspects:**
#
# * **String Literals:** In Python, strings are enclosed in quotes. Single quotes '...' and double quotes "...") are both valid for creating string literals.
# * **print() Function:** This function is used to output its argument(s) to the console. It can take multiple arguments separated by commas.
#
# **Implications:**
#
# This code demonstrates the basic functionality of printing a string to the console in Python. It's a fundamental building block for more complex programming tasks and sets the stage for learning other aspects of the language, such as variables, data structures, control flow, and more.
#
# In summary, this code is a straightforward print statement that outputs a simple greeting message to the console.
# Embeddings: [128006, 882, 128007, 271, 2127, 56956, 279, 2768, 2082, 323, 1893, 264, 11944, 40188, 430, 41255, 1202, 15293, 323, 6070, 1473, 1374, 493, 9906, 11, 4435, 0, 873, 128009, 128006, 78191, 128007, 271, 3923, 264, 11670, 2268, 8586, 596, 264, 11944, 6492, 315, 279, 2082, 1473, 334, 5263, 2786, 25, 57277, 791, 3984, 2082, 374, 264, 4382, 1194, 5224, 304, 13325, 13, 3277, 16070, 11, 433, 690, 2612, 279, 925, 330, 9906, 11, 4435, 9135, 311, 279, 2393, 382, 334, 23807, 25, 57277, 791, 2082, 17610, 315, 264, 3254, 1584, 430, 5727, 1473, 16, 13, 578, 1595, 1374, 55358, 734, 25, 1115, 374, 264, 5918, 3502, 13325, 734, 1511, 311, 2612, 1202, 5811, 1161, 8, 311, 279, 2393, 627, 17, 13, 362, 24116, 925, 25, 578, 925, 330, 9906, 11, 4435, 9135, 374, 44910, 304, 17637, 320, 50998, 3254, 17637, 364, 74438, 477, 2033, 17637, 39813, 1865, 1115, 15151, 430, 279, 8970, 2949, 527, 264, 24016, 925, 382, 334, 23340, 2996, 315, 279, 6247, 25, 57277, 8586, 596, 264, 3094, 14656, 30308, 31085, 315, 1148, 8741, 994, 420, 2082, 374, 16070, 1473, 16, 13, 578, 1595, 1374, 55358, 734, 374, 2663, 449, 279, 5811, 54405, 9906, 11, 4435, 9135, 19154, 17, 13, 578, 13325, 40399, 35006, 279, 24116, 925, 323, 32839, 433, 439, 264, 24016, 907, 627, 18, 13, 578, 1595, 1374, 55358, 734, 5097, 279, 24116, 925, 439, 1988, 323, 16674, 433, 311, 279, 2393, 1701, 279, 5452, 596, 1670, 2612, 17383, 320, 68, 1326, 2637, 20676, 4390, 19, 13, 578, 2612, 374, 12882, 304, 279, 2393, 477, 15372, 3321, 11, 9204, 279, 925, 330, 9906, 11, 4435, 9135, 382, 334, 1622, 1666, 8132, 25, 57277, 9, 3146, 707, 26550, 1147, 68063, 763, 13325, 11, 9246, 527, 44910, 304, 17637, 13, 11579, 17637, 364, 74438, 323, 2033, 17637, 39813, 909, 527, 2225, 2764, 369, 6968, 925, 76375, 627, 9, 3146, 1374, 368, 5830, 68063, 1115, 734, 374, 1511, 311, 2612, 1202, 5811, 1161, 8, 311, 279, 2393, 13, 1102, 649, 1935, 5361, 6105, 19180, 555, 77702, 382, 334, 26282, 10939, 25, 57277, 2028, 2082, 32216, 279, 6913, 15293, 315, 18991, 264, 925, 311, 279, 2393, 304, 13325, 13, 1102, 596, 264, 16188, 4857, 2565, 369, 810, 6485, 15840, 9256, 323, 7437, 279, 6566, 369, 6975, 1023, 13878, 315, 279, 4221, 11, 1778, 439, 7482, 11, 828, 14726, 11, 2585, 6530, 11, 323, 810, 382, 644, 12399, 11, 420, 2082, 374, 264, 31439, 1194, 5224, 430, 16674, 264, 4382, 43213, 1984, 311, 279, 2393, 13]

# %% [markdown]
#  # Test Database connection to local Postgres DB running in a container

# %%
import psycopg2
from psycopg2 import sql

# %%
db_params = {
    'dbname': 'postgres',
    'user': 'postgres',
    'password': 'mysecretpassword',
    'host': '172.18.0.3',
    'port': '5432'
}

try:
    # Establish the connection
    conn = psycopg2.connect(**db_params)
    cur = conn.cursor()

    # Run a query to fetch column names
    cur.execute("SELECT * FROM code_files LIMIT 0")
    column_names = [desc[0] for desc in cur.description]

    print("Column names:", column_names)

    # Close the cursor and connection
    cur.close()
    conn.close()

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Column names: ['id', 'file_explanation', 'file_path', 'updated_at_time', 'file_name', 'file_explanation_embedding']

# %% [markdown]
# # Create embeddings for each code file in a repository

# %%
import os
import glob
import requests
import psycopg2
from psycopg2.extras import execute_values
from datetime import datetime

# %%
# Function to fetch all files in the project directory
def fetch_files(project_directory):
    file_paths = glob.glob(os.path.join(project_directory, '**', '*'), recursive=True)
    files = [path for path in file_paths if os.path.isfile(path)]
    return files

# %%
# Function to generate embeddings using the LLaMA model API
def generate_embeddings(file_content):
    url = "http://172.18.0.2:11434/api/generate" 
    headers = {'Content-Type': 'application/json'}
    
    data = {'prompt': f"Analyze the following code and create a detailed embedding that captures its functionality and structure:\n\n{file_content}",
            'model': 'llama3'
           }
    
    response = requests.post(url, headers=headers, json=data, stream=True)
    
    if response.status_code == 200:
        full_response = ""
        embeddings = []
        for line in response.iter_lines():
            if line:
                json_response = json.loads(line.decode('utf-8'))
                full_response += json_response.get('response', '')
                if 'context' in json_response:
                    embeddings = json_response['context']
                if json_response.get('done', False):
                    break
        return full_response, embeddings
    else:
        raise Exception(f"Failed to generate embeddings: {response.status_code} - {response.text}")

# %%
def store_in_db(conn, file_path, file_name, explanation, embeddings):
    cur = conn.cursor()
    
    cur.execute("ALTER TABLE code_files DROP COLUMN IF EXISTS file_explanation_embedding")
    cur.execute("ALTER TABLE code_files ADD COLUMN file_explanation_embedding jsonb")
    query = sql.SQL("INSERT INTO vector_database (file_path, file_name, file_explanation, file_explanation_embedding, updated_at_time) VALUES (%s, %s, %s, %s, %s)")
    cur.execute(query, (file_path, file_name, explanation, json.dumps(embeddings), datetime.now()))
    conn.commit()
    cur.close()

# %%
db_params = {
    'dbname': 'postgres',
    'user': 'postgres',
    'password': 'mysecretpassword',
    'host': '172.18.0.3', 
    'port': '5432'
}

conn = psycopg2.connect(**db_params)

project_repo_path = '../repos/ToolTime/'

# Iterate over files in the directory
for root, dirs, files in os.walk(project_repo_path):
    for file in files:
        file_path = os.path.join(root, file)
        
        try:
            with open(file_path, 'r', encoding='utf-8') as f:
                file_content = f.read()
        except UnicodeDecodeError:
            with open(file_path, 'r', encoding='utf-8', errors='ignore') as f:
                file_content = f.read()
        
        # Remove null characters from file content
        file_content = file_content.replace('\x00', '')
        
        # Generate explanation and embeddings
        explanation, embeddings = generate_embeddings(file_content)
        
        # Store in database
        store_in_db(conn, file_path, file, explanation, embeddings)

conn.close()

# %%
import psycopg2
import pandas as pd

db_params = {
    'dbname': 'postgres',
    'user': 'postgres',
    'password': 'mysecretpassword',
    'host': '172.18.0.3',
    'port': '5432'
}

try:
    conn = psycopg2.connect(**db_params)
    cur = conn.cursor()

    cur.execute("SELECT * FROM vector_database")
    
    rows = cur.fetchall()

    column_names = [desc[0] for desc in cur.description]

    df = pd.DataFrame(rows, columns=column_names)
    
    # Close the cursor and connection
    cur.close()
    conn.close()

except Exception as e:
    print(f"An error occurred: {e}")

# %%
df.head(25)
# Out:
#      id                                   file_explanation  \
# 0     1  This is a JSON file that represents a package....
# 1     2  **Overview**\n\nThe provided code is a JSON fi...
# 2     3  What an intriguing piece of code!\n\nAfter ana...
# 3     4  What a fascinating code snippet!\n\nThe provid...
# 4     5  Here is a detailed embedding of the code and i...
# 5   115  What a delightfully concise piece of code!\n\n...
# 6     6  The provided code snippet appears to be a dire...
# 7     7  **Code Analysis**\n\nThe provided code is a JS...
# 8     8  What an interesting piece of code!\n\n**Overvi...
# 9     9  Here's a detailed analysis of the given code:\...
# 10   10  What an interesting piece of code!\n\n**Functi...
# 11   16  **Code Analysis**\n\nThe provided code is a Re...
# 12   11  **Embedding Analysis**\n\nThis is a JSON file,...
# 13   12  What an interesting piece of code!\n\n**Functi...
# 14   13  **Embedding:**\n\nThe code is a JavaScript fil...
# 15   14  What a fascinating piece of code!\n\nThe provi...
# 16   15  A fascinating piece of code!\n\nAt first glanc...
# 17   17  What a fascinating piece of code!\n\nThe provi...
# 18   18  What an interesting piece of code!\n\nAfter an...
# 19   19  What a fascinating piece of code!\n\nAt first ...
# 20   20  What an intriguing piece of code!\n\nAt first ...
# 21   21  A fascinating piece of code!\n\nAfter analyzin...
# 22   22  A fascinating piece of code!\n\n**Functionalit...
# 23   23  **Overview**\n\nThe `CreateEntry` component is...
# 24   24  **Functionality**\n\nThe `CreateEntry` class i...
#
#                            file_explanation_embedding  \
# 0   [128006, 882, 128007, 271, 2127, 56956, 279, 2...
# 1   [128006, 882, 128007, 271, 2127, 56956, 279, 2...
# 2   [128006, 882, 128007, 271, 2127, 56956, 279, 2...
# 3   [128006, 882, 128007, 271, 2127, 56956, 279, 2...
# 4   [128006, 882, 128007, 271, 2127, 56956, 279, 2...
# 5   [128006, 882, 128007, 271, 2127, 56956, 279, 2...
# 6   [128006, 882, 128007, 271, 2127, 56956, 279, 2...
# 7   [128006, 882, 128007, 271, 2127, 56956, 279, 2...
# 8   [128006, 882, 128007, 271, 2127, 56956, 279, 2...
# 9   [128006, 882, 128007, 271, 2127, 56956, 279, 2...
# 10  [128006, 882, 128007, 271, 2127, 56956, 279, 2...
# 11  [128006, 882, 128007, 271, 2127, 56956, 279, 2...
# 12  [128006, 882, 128007, 271, 2127, 56956, 279, 2...
# 13  [128006, 882, 128007, 271, 2127, 56956, 279, 2...
# 14  [128006, 882, 128007, 271, 2127, 56956, 279, 2...
# 15  [128006, 882, 128007, 271, 2127, 56956, 279, 2...
# 16  [128006, 882, 128007, 271, 2127, 56956, 279, 2...
# 17  [128006, 882, 128007, 271, 2127, 56956, 279, 2...
# 18  [128006, 882, 128007, 271, 2127, 56956, 279, 2...
# 19  [128006, 882, 128007, 271, 2127, 56956, 279, 2...
# 20  [128006, 882, 128007, 271, 2127, 56956, 279, 2...
# 21  [128006, 882, 128007, 271, 2127, 56956, 279, 2...
# 22  [128006, 882, 128007, 271, 2127, 56956, 279, 2...
# 23  [128006, 882, 128007, 271, 2127, 56956, 279, 2...
# 24  [128006, 882, 128007, 271, 2127, 56956, 279, 2...
#
#                                           file_path  \
# 0               ../repos/ToolTime/package-lock.json
# 1                       ../repos/ToolTime/yarn.lock
# 2                  ../repos/ToolTime/._node_modules
# 3                         ../repos/ToolTime/._.expo
# 4                       ../repos/ToolTime/README.md
# 5   ../repos/ToolTime/.git/refs/remotes/origin/HEAD
# 6                      ../repos/ToolTime/.gitignore
# 7                        ../repos/ToolTime/app.json
# 8                       ../repos/ToolTime/._.vscode
# 9                 ../repos/ToolTime/babel.config.js
# 10                          ../repos/ToolTime/._app
# 11                         ../repos/ToolTime/App.js
# 12                   ../repos/ToolTime/package.json
# 13                         ../repos/ToolTime/._.git
# 14                    ../repos/ToolTime/firebase.js
# 15                 ../repos/ToolTime/._.expo-shared
# 16                    ../repos/ToolTime/._.DS_Store
# 17                   ../repos/ToolTime/app/._config
# 18                   ../repos/ToolTime/app/._assets
# 19               ../repos/ToolTime/app/._navigation
# 20               ../repos/ToolTime/app/._components
# 21                  ../repos/ToolTime/app/._screens
# 22                ../repos/ToolTime/app/._.DS_Store
# 23        ../repos/ToolTime/app/screens/ToDoList.js
# 24     ../repos/ToolTime/app/screens/CreateEntry.js
#
#               updated_at_time          file_name
# 0  2024-07-29 03:32:11.588029  package-lock.json
# 1  2024-07-29 03:32:19.917888          yarn.lock
# 2  2024-07-29 03:32:27.439816     ._node_modules
# 3  2024-07-29 03:32:35.546389            ._.expo
# 4  2024-07-29 03:32:43.668070          README.md
# 5  2024-07-29 03:52:30.558617               HEAD
# 6  2024-07-29 03:32:52.089596         .gitignore
# 7  2024-07-29 03:32:59.807773           app.json
# 8  2024-07-29 03:33:07.905993          ._.vscode
# 9  2024-07-29 03:33:17.034805    babel.config.js
# 10 2024-07-29 03:33:26.686924              ._app
# 11 2024-07-29 03:34:24.234766             App.js
# 12 2024-07-29 03:33:34.404296       package.json
# 13 2024-07-29 03:33:44.819831             ._.git
# 14 2024-07-29 03:33:54.024160        firebase.js
# 15 2024-07-29 03:34:03.353201     ._.expo-shared
# 16 2024-07-29 03:34:13.335361        ._.DS_Store
# 17 2024-07-29 03:34:34.041202           ._config
# 18 2024-07-29 03:34:41.303456           ._assets
# 19 2024-07-29 03:34:50.675512       ._navigation
# 20 2024-07-29 03:34:59.380397       ._components
# 21 2024-07-29 03:35:08.034031          ._screens
# 22 2024-07-29 03:35:15.133338        ._.DS_Store
# 23 2024-07-29 03:35:26.943335        ToDoList.js
# 24 2024-07-29 03:35:37.915074     CreateEntry.js
